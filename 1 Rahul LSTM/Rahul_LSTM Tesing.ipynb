# %%
import Rahul_LSTM
# Out:
# Epoch 1/20
# 14/14 [==============================] - 14s 362ms/step - loss: 0.0166 - val_loss: 0.1170
# Epoch 2/20
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0069 - val_loss: 0.1309
# Epoch 3/20
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0028 - val_loss: 0.0061
# Epoch 4/20
# 14/14 [==============================] - 0s 30ms/step - loss: 6.8829e-04 - val_loss: 0.0137
# Epoch 5/20
# 14/14 [==============================] - 0s 30ms/step - loss: 5.7714e-04 - val_loss: 0.0056
# Epoch 6/20
# 14/14 [==============================] - 0s 30ms/step - loss: 6.3130e-04 - val_loss: 0.0092
# Epoch 7/20
# 14/14 [==============================] - 0s 31ms/step - loss: 5.5282e-04 - val_loss: 0.0056
# Epoch 8/20
# 14/14 [==============================] - 0s 31ms/step - loss: 5.3517e-04 - val_loss: 0.0061
# Epoch 9/20
# 14/14 [==============================] - 0s 28ms/step - loss: 5.2677e-04 - val_loss: 0.0053
# Epoch 10/20
# ...

# %%
data = Rahul_LSTM.Data_Fetching("ETH", "USD", 100)
data
# Out:
#                High      Low     Open    Close   DateTime
# Date
# 2021-01-14  1246.36  1087.39  1129.84  1232.11 2021-01-14
# 2021-01-15  1255.19  1069.37  1232.11  1169.06 2021-01-15
# 2021-01-16  1293.20  1152.92  1169.06  1228.52 2021-01-16
# 2021-01-17  1269.49  1166.60  1228.52  1233.73 2021-01-17
# 2021-01-18  1260.68  1183.78  1233.73  1258.31 2021-01-18
# ...             ...      ...      ...      ...        ...
# 2021-04-20  2348.17  2055.51  2163.36  2332.45 2021-04-20
# 2021-04-21  2469.05  2238.47  2332.45  2357.59 2021-04-21
# 2021-04-22  2644.50  2310.62  2357.59  2401.35 2021-04-22
# 2021-04-23  2441.96  2096.00  2401.35  2369.67 2021-04-23
# 2021-04-24  2370.67  2178.97  2369.67  2183.70 2021-04-24
#
# [101 rows x 5 columns]

# %%
Rahul_LSTM.Predication_Next_Days(data['Close'], 100, 0.90, 2, 2)
# Out:
# Epoch 1/20
# 2/2 [==============================] - 12s 2s/step - loss: 0.2102 - val_loss: 0.7089
# Epoch 2/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1929 - val_loss: 0.6828
# Epoch 3/20
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1941 - val_loss: 0.6555
# Epoch 4/20
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1791 - val_loss: 0.6260
# Epoch 5/20
# 2/2 [==============================] - 0s 89ms/step - loss: 0.1671 - val_loss: 0.5938
# Epoch 6/20
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1501 - val_loss: 0.5582
# Epoch 7/20
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1417 - val_loss: 0.5187
# Epoch 8/20
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1251 - val_loss: 0.4748
# Epoch 9/20
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1154 - val_loss: 0.4264
# Epoch 10/20
# ...
